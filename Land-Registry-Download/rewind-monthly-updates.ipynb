# %%
import io
import pandas
import dotenv

import boto3
import botocore

from sqlalchemy import Engine
from sqlalchemy import create_engine
from sqlalchemy.orm import Session

from lib_land_registry_data.lib_db import PPMonthlyUpdateArchiveFileLog
from lib_land_registry_data.lib_env import EnvironmentVariables

# %%
dotenv.load_dotenv('.envrc')
# Out:
# True

# %%
environment_variables = EnvironmentVariables()

# %%
pp_complete_file = f'/data-land-registry/pp-complete/archive/pp-complete-2024-07-27.txt'

# %%
df = pandas.read_csv(
    pp_complete_file,
    header=None,
)

# %%
df_columns = [
    'transaction_unique_id',
    'price',
    'transaction_date',
    'postcode',
    'property_type',
    'new_tag',
    'lease',
    'primary_address_object_name',
    'secondary_address_object_name',
    'street',
    'locality',
    'town_city',
    'district',
    'county',
    'ppd_cat',
    'record_status',
]

# %%
df.columns = df_columns

# %%
df
# Out:
#                            transaction_unique_id    price  transaction_date  \
# 0         {5BBE9CB3-6332-4EB0-9CD3-8737CEA4A65A}    42000  1995-12-21 00:00
# 1         {20E2441A-0F16-49AB-97D4-8737E62A5D93}    95000  1995-03-03 00:00
# 2         {D893EE64-4464-44B5-B01B-8E62403ED83C}    74950  1995-10-03 00:00
# 3         {F9F753A8-E56A-4ECC-9927-8E626A471A92}    43500  1995-11-14 00:00
# 4         {E166398A-A19E-470E-BB5A-83B4C254CF6D}    63000  1995-09-08 00:00
# ...                                          ...      ...               ...
# 29299981  {12A8BAB6-EB70-2125-E063-4804A8C08CC1}    50000  2024-01-19 00:00
# 29299982  {12A8BAB6-EB71-2125-E063-4804A8C08CC1}   246000  2024-02-19 00:00
# 29299983  {12A8BAB6-EB74-2125-E063-4804A8C08CC1}   250000  2024-02-01 00:00
# 29299984  {12A8BAB6-EB7A-2125-E063-4804A8C08CC1}   775000  2024-01-31 00:00
# 29299985  {12A8BAB6-EB80-2125-E063-4804A8C08CC1}  2200000  2024-01-31 00:00
#
#           postcode property_type new_tag lease primary_address_object_name  \
# 0          NE4 9DN             S       N     F                           8
# 1         RM16 4UR             S       N     F                          30
# 2         CW10 9ES             D       Y     F                          15
# 3         TS23 3LA             S       N     F                          19
# 4         CA25 5QH             S       N     F                           8
# ...            ...           ...     ...   ...                         ...
# 29299981   TQ2 5PL             O       N     F                          10
# 29299982  EX32 7RL             T       N     F                          56
# 29299983  PL16 0LD             O       N     L                    LYD VALE
# 29299984  EX39 2RL             O       N     F               DYERS LOOKOUT
# 29299985   EX2 8RB             O       N     F                           2
#
#          secondary_address_object_name              street  \
# 0                                  NaN        MATFEN PLACE
# 1                                  NaN          HEATH ROAD
# 2                                  NaN    SHROPSHIRE CLOSE
# 3                                  NaN      SLEDMERE CLOSE
# 4                                  NaN     CROSSINGS CLOSE
# ...                                ...                 ...
# 29299981                           NaN        UNION STREET
# 29299982                           NaN  SILVERWOOD HEIGHTS
# 29299983                      GARAGE 2           OAK RIDGE
# 29299984                           NaN        DURRANT LANE
# 29299985                           NaN        TRUSHAM ROAD
#
#                              locality            town_city  \
# 0                              FENHAM  NEWCASTLE UPON TYNE
# 1                               GRAYS                GRAYS
# 2                          MIDDLEWICH           MIDDLEWICH
# 3                          BILLINGHAM           BILLINGHAM
# 4                        CLEATOR MOOR         CLEATOR MOOR
# ...                               ...                  ...
# 29299981                          NaN              TORQUAY
# 29299982                          NaN           BARNSTAPLE
# 29299983                          NaN               LIFTON
# 29299984                      NORTHAM             BIDEFORD
# 29299985  MARSH BARTON TRADING ESTATE               EXETER
#
#                      district            county ppd_cat record_status
# 0         NEWCASTLE UPON TYNE     TYNE AND WEAR       A             A
# 1                    THURROCK          THURROCK       A             A
# 2                   CONGLETON          CHESHIRE       A             A
# 3            STOCKTON-ON-TEES  STOCKTON-ON-TEES       A             A
# 4                    COPELAND           CUMBRIA       A             A
# ...                       ...               ...     ...           ...
# 29299981               TORBAY            TORBAY       B             A
# 29299982          NORTH DEVON             DEVON       B             A
# 29299983           WEST DEVON             DEVON       B             A
# 29299984             TORRIDGE             DEVON       B             A
# 29299985               EXETER             DEVON       B             A
#
# [29299986 rows x 16 columns]

# %%
postgres_connection_string = environment_variables.get_postgres_connection_string()
postgres_engine = create_engine(postgres_connection_string)

# %%
with Session(postgres_engine) as session:
    rows = (
        session
        .query(PPMonthlyUpdateArchiveFileLog)
        .order_by(PPMonthlyUpdateArchiveFileLog.pp_monthly_update_archive_file_log_id)
        .all()
    )

print(f'number of rows loaded: {len(rows)}')
# Out:
# number of rows loaded: 114

# %%
aws_access_key_id = environment_variables.get_aws_access_key_id()
aws_secret_access_key = environment_variables.get_aws_secret_access_key()
minio_url = environment_variables.get_minio_url()

boto3_session = boto3.Session(
    aws_access_key_id=aws_access_key_id,
    aws_secret_access_key=aws_secret_access_key,
)

# %%
print(f'current pp-complete dataframe contains {len(df)} rows')
# Out:
# current pp-complete dataframe contains 29299986 rows

# %%
df_copy = df.copy()

# %%
df['transaction_unique_id'].value_counts().max()
# Out:
# np.int64(1)

# %%
df_month_list = []

for row in rows:
    pp_monthly_update_archive_file_log_id = row.pp_monthly_update_archive_file_log_id
    data_timestamp = row.data_timestamp
    data_timestamp_str = data_timestamp.strftime('%Y-%m-%d')
    print(f'processing row {data_timestamp_str=}')

    s3_bucket = row.s3_bucket
    s3_object_key = row.s3_object_key

    boto3_client = (
        boto3_session.client(
            's3',
            endpoint_url=minio_url,
            config=botocore.config.Config(signature_version='s3v4'),
        )
    )

    print(f'loading {s3_bucket}/{s3_object_key}')

    s3_response_object = boto3_client.get_object(Bucket=s3_bucket, Key=s3_object_key)
    pp_monthly_update_data = s3_response_object['Body'].read()

    df_current_month = pandas.read_csv(
        io.BytesIO(pp_monthly_update_data),
        header=None,
    )
    print(f'current month df contains {len(df_current_month)} rows')

    if len(df_current_month.columns) == 16:
        pass
    elif len(df_current_month.columns) == 15:
        df_current_month['ppd_cat'] = None
    else:
        raise RuntimeError(f'invalid number of columns: {len(df_current_month.columns)}')

    df_current_month.columns = df_columns

    # check no duplicate transaction_unique_id in this months dataframe
    df_current_month_tuid_value_counts = df_current_month['transaction_unique_id'].value_counts()

    vc_gt = df_current_month_tuid_value_counts[df_current_month_tuid_value_counts > 1]
    if len(vc_gt) > 0:
        print(vc_gt)

    df_tuid_dup = df_current_month[df_current_month['transaction_unique_id'].isin(vc_gt.index)].copy()
    df_tuid_dup.reset_index(inplace=True)
    if len(df_tuid_dup) > 0:
        print(f'duplicate transaction_unique_id detected')
        print(df_tuid_dup)
        df_tuid_dup.sort_values(by='transaction_unique_id').to_csv(f'df_tuid_dup_{data_timestamp_str}.csv')

    df_month_list.append(df_current_month)

df_months = pandas.concat(df_month_list, ignore_index=True)
# Out:
# processing row data_timestamp_str='2015-01-31'
# loading land-registry-data-archive/PPMS_update_2015_1_31.txt
# current month df contains 83245 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-02-28'
# loading land-registry-data-archive/PPMS_update_2015_2_28.txt
# current month df contains 69326 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-03-31'
# loading land-registry-data-archive/PPMS_update_2015_3_31.txt
# current month df contains 78891 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-04-30'
# loading land-registry-data-archive/PPMS_update_2015_4_30.txt
# current month df contains 70097 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-05-31'
# loading land-registry-data-archive/PPMS_update_2015_5_31.txt
# current month df contains 65902 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-06-30'
# loading land-registry-data-archive/PPMS_update_2015_6_30.txt
# current month df contains 81232 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-07-31'
# loading land-registry-data-archive/PPMS_update_2015_7_31.txt
# current month df contains 90778 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-08-31'
# loading land-registry-data-archive/PPMS_update_2015_8_31.txt
# current month df contains 83713 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-09-30'
# loading land-registry-data-archive/PPMS_update_2015_9_30.txt
# current month df contains 102520 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-10-31'
# loading land-registry-data-archive/PPMS_update_2015_10_31.txt
# current month df contains 103354 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-11-30'
# loading land-registry-data-archive/PPMS_update_2015_11_30.txt
# current month df contains 101560 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2015-12-31'
# loading land-registry-data-archive/PPMS_update_2015_12_31.txt
# current month df contains 110042 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-01-31'
# loading land-registry-data-archive/PPMS_update_2016_1_31.txt
# current month df contains 418582 rows
# transaction_unique_id
# {2A289E9D-2FB5-CDC8-E050-A8C063054829}    2
# {2A289E9D-36B1-CDC8-E050-A8C063054829}    2
# {2A289E9E-302F-CDC8-E050-A8C063054829}    2
# {2A289E9F-4CB0-CDC8-E050-A8C063054829}    2
# {2A289E9C-F5C6-CDC8-E050-A8C063054829}    2
#                                          ..
# {2A289EA0-B9F9-CDC8-E050-A8C063054829}    2
# {2A289E9F-75E0-CDC8-E050-A8C063054829}    2
# {2A289E9D-A4FC-CDC8-E050-A8C063054829}    2
# {2A289E9E-02E0-CDC8-E050-A8C063054829}    2
# {2A289EA1-22A0-CDC8-E050-A8C063054829}    2
# Name: count, Length: 179, dtype: int64
#                          transaction_unique_id   price  transaction_date  \
# 5775    {2A289E9F-79BE-CDC8-E050-A8C063054829}  170000  2003-02-03 00:00
# 5776    {2A289E9E-7EE1-CDC8-E050-A8C063054829}   82000  2003-10-16 00:00
# 5777    {2A289E9F-271E-CDC8-E050-A8C063054829}  215000  2003-07-16 00:00
# 5778    {2A289E9E-D788-CDC8-E050-A8C063054829}  280000  2003-09-26 00:00
# 5779    {2A289E9E-7253-CDC8-E050-A8C063054829}  672000  2003-03-25 00:00
# ...                                        ...     ...               ...
# 412782  {2A289E9F-B48B-CDC8-E050-A8C063054829}  145000  2012-03-20 00:00
# 413828  {2A289E9F-B909-CDC8-E050-A8C063054829}  185000  2012-02-21 00:00
# 416901  {2A289E9F-12C9-CDC8-E050-A8C063054829}  170000  2012-03-12 00:00
# 416922  {2A289E9F-3FF4-CDC8-E050-A8C063054829}  180000  2012-08-02 00:00
# 418560  {288DCE29-6E09-E510-E050-A8C06205480E}   64950  2015-09-16 00:00
#
#         postcode property_type new_tag lease primary_address_object_name  \
# 5775    WF17 5LD             D       N     F                           3
# 5776     NN8 3HX             T       Y     F                        162A
# 5777     CA7 9NH             D       N     F               KILDARE HOUSE
# 5778     HR9 7UP             D       N     F                 BROOK HOUSE
# 5779     EN4 0JT             D       N     F      RENAISSANCE HOUSE, 359
# ...          ...           ...     ...   ...                         ...
# 412782  NW10 8TR             T       N     F                          4B
# 413828   TQ9 7AH             F       N     L              SHEPLEGH COURT
# 416901  DE21 2SF             D       N     F                         45A
# 416922  PE21 7LR             D       N     F                          1B
# 418560    L8 5RZ             F       Y     L                          25
#
#        secondary_address_object_name            street      locality  \
# 5775                             NaN    PROSPECT COURT           NaN
# 5776                             NaN    WESTFIELD ROAD           NaN
# 5777                               1       CROFT COURT           NaN
# 5778                             NaN               NaN  UPTON BISHOP
# 5779                             NaN  COCKFOSTERS ROAD           NaN
# ...                              ...               ...           ...
# 412782                           NaN      MANOR PARADE           NaN
# 413828                             8               NaN    BLACKAWTON
# 416901                           NaN     SMALLEY DRIVE       OAKWOOD
# 416922                           NaN     WEST END ROAD      WYBERTON
# 418560                 APARTMENT 103   PLAZA BOULEVARD           NaN
#
#              town_city        district            county ppd_cat record_status
# 5775            BATLEY        KIRKLEES    WEST YORKSHIRE       A             C
# 5776    WELLINGBOROUGH  WELLINGBOROUGH  NORTHAMPTONSHIRE       A             C
# 5777            WIGTON       ALLERDALE           CUMBRIA       A             C
# 5778       ROSS-ON-WYE   HEREFORDSHIRE     HEREFORDSHIRE       A             C
# 5779            BARNET         ENFIELD    GREATER LONDON       A             C
# ...                ...             ...               ...     ...           ...
# 412782          LONDON           BRENT    GREATER LONDON       A             A
# 413828          TOTNES      SOUTH HAMS             DEVON       A             A
# 416901           DERBY   CITY OF DERBY     CITY OF DERBY       A             A
# 416922          BOSTON          BOSTON      LINCOLNSHIRE       A             A
# 418560       LIVERPOOL       LIVERPOOL        MERSEYSIDE       A             C
#
# [358 rows x 16 columns]
# duplicate transaction_unique_id detected
# processing row data_timestamp_str='2016-02-29'
# loading land-registry-data-archive/PPMS_update_2016_2_29.txt
# current month df contains 95728 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-03-31'
# loading land-registry-data-archive/PPMS_update_2016_3_31.txt
# current month df contains 96913 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-04-30'
# loading land-registry-data-archive/PPMS_update_2016_4_30.txt
# current month df contains 125488 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-05-31'
# loading land-registry-data-archive/PPMS_update_2016_5_31.txt
# current month df contains 82605 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-06-30'
# loading land-registry-data-archive/PPMS_update_2016_6_30.txt
# current month df contains 88970 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-07-31'
# loading land-registry-data-archive/PPMS_update_2016_7_31.txt
# current month df contains 92434 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-08-31'
# loading land-registry-data-archive/PPMS_update_2016_8_31.txt
# current month df contains 96415 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-09-30'
# loading land-registry-data-archive/PPMS_update_2016_9_30.txt
# current month df contains 102078 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-10-31'
# loading land-registry-data-archive/PPMS_update_2016_10_31.txt
# current month df contains 100842 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-11-30'
# loading land-registry-data-archive/PPMS_update_2016_11_30.txt
# current month df contains 105554 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2016-12-31'
# loading land-registry-data-archive/PPMS_update_2016_12_31.txt
# current month df contains 94248 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-01-31'
# loading land-registry-data-archive/PPMS_update_2017_1_31.txt
# current month df contains 104773 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-02-28'
# loading land-registry-data-archive/PPMS_update_2017_2_28.txt
# current month df contains 91067 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-03-31'
# loading land-registry-data-archive/PPMS_update_2017_3_31.txt
# current month df contains 104462 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-04-30'
# loading land-registry-data-archive/PPMS_update_2017_4_30.txt
# current month df contains 81332 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-05-31'
# loading land-registry-data-archive/PPMS_update_2017_5_31.txt
# current month df contains 93831 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-06-30'
# loading land-registry-data-archive/PPMS_update_2017_6_30.txt
# current month df contains 99125 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-07-31'
# loading land-registry-data-archive/PPMS_update_2017_7_31.txt
# current month df contains 100484 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-08-31'
# loading land-registry-data-archive/PPMS_update_2017_8_31.txt
# current month df contains 106178 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-09-30'
# loading land-registry-data-archive/PPMS_update_2017_9_30.txt
# current month df contains 104533 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-10-31'
# loading land-registry-data-archive/PPMS_update_2017_10_31.txt
# current month df contains 108822 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-11-30'
# loading land-registry-data-archive/PPMS_update_2017_11_30.txt
# current month df contains 175877 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2017-12-31'
# loading land-registry-data-archive/PPMS_update_2017_12_31.txt
# current month df contains 83538 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-01-31'
# loading land-registry-data-archive/PPMS_update_2018_1_31.txt
# current month df contains 130366 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-02-28'
# loading land-registry-data-archive/PPMS_update_2018_2_28.txt
# current month df contains 92821 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-03-31'
# loading land-registry-data-archive/PPMS_update_2018_3_31.txt
# current month df contains 107183 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-04-30'
# loading land-registry-data-archive/PPMS_update_2018_4_30.txt
# current month df contains 85682 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-05-31'
# loading land-registry-data-archive/PPMS_update_2018_5_31.txt
# current month df contains 90858 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-06-30'
# loading land-registry-data-archive/PPMS_update_2018_6_30.txt
# current month df contains 92672 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-07-31'
# loading land-registry-data-archive/PPMS_update_2018_7_31.txt
# current month df contains 103373 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-08-31'
# loading land-registry-data-archive/PPMS_update_2018_8_31.txt
# current month df contains 107712 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-09-30'
# loading land-registry-data-archive/PPMS_update_2018_9_30.txt
# current month df contains 104308 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-10-31'
# loading land-registry-data-archive/PPMS_update_2018_10_31.txt
# current month df contains 115219 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-11-30'
# loading land-registry-data-archive/PPMS_update_2018_11_30.txt
# current month df contains 111213 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2018-12-31'
# loading land-registry-data-archive/PPMS_update_2018_12_31.txt
# current month df contains 95475 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-01-31'
# loading land-registry-data-archive/PPMS_update_2019_1_31.txt
# current month df contains 108837 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-02-28'
# loading land-registry-data-archive/PPMS_update_2019_2_28.txt
# current month df contains 89667 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-03-31'
# loading land-registry-data-archive/PPMS_update_2019_3_31.txt
# current month df contains 95943 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-04-30'
# loading land-registry-data-archive/PPMS_update_2019_4_30.txt
# current month df contains 81624 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-05-31'
# loading land-registry-data-archive/PPMS_update_2019_5_31.txt
# current month df contains 92591 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-06-30'
# loading land-registry-data-archive/PPMS_update_2019_6_30.txt
# current month df contains 88978 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-07-31'
# loading land-registry-data-archive/PPMS_update_2019_7_31.txt
# current month df contains 100976 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-08-31'
# loading land-registry-data-archive/PPMS_update_2019_8_31.txt
# current month df contains 100789 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-09-30'
# loading land-registry-data-archive/PPMS_update_2019_9_30.txt
# current month df contains 99727 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-10-31'
# loading land-registry-data-archive/PPMS_update_2019_10_31.txt
# current month df contains 103483 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-11-30'
# loading land-registry-data-archive/PPMS_update_2019_11_30.txt
# current month df contains 99994 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2019-12-31'
# loading land-registry-data-archive/PPMS_update_2019_12_31.txt
# current month df contains 90687 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-01-31'
# loading land-registry-data-archive/PPMS_update_2020_1_31.txt
# current month df contains 104817 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-02-29'
# loading land-registry-data-archive/PPMS_update_2020_2_29.txt
# current month df contains 86038 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-03-31'
# loading land-registry-data-archive/PPMS_update_2020_3_31.txt
# current month df contains 60529 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-04-30'
# loading land-registry-data-archive/PPMS_update_2020_4_30.txt
# current month df contains 2029 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-05-31'
# loading land-registry-data-archive/PPMS_update_2020_5_31.txt
# current month df contains 28852 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-06-30'
# loading land-registry-data-archive/PPMS_update_2020_6_30.txt
# current month df contains 77589 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-07-31'
# loading land-registry-data-archive/PPMS_update_2020_7_31.txt
# current month df contains 67672 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-08-31'
# loading land-registry-data-archive/PPMS_update_2020_8_31.txt
# current month df contains 67788 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-09-30'
# loading land-registry-data-archive/PPMS_update_2020_9_30.txt
# current month df contains 65497 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-10-31'
# loading land-registry-data-archive/PPMS_update_2020_10_31.txt
# current month df contains 70767 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-11-30'
# loading land-registry-data-archive/PPMS_update_2020_11_30.txt
# current month df contains 71521 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2020-12-31'
# loading land-registry-data-archive/PPMS_update_2020_12_31.txt
# current month df contains 92551 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-01-31'
# loading land-registry-data-archive/PPMS_update_2021_1_31.txt
# current month df contains 103608 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-02-28'
# loading land-registry-data-archive/PPMS_update_2021_2_28.txt
# current month df contains 88121 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-03-31'
# loading land-registry-data-archive/PPMS_update_2021_3_31.txt
# current month df contains 87085 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-04-30'
# loading land-registry-data-archive/PPMS_update_2021_4_30.txt
# current month df contains 95312 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-05-31'
# loading land-registry-data-archive/PPMS_update_2021_5_31.txt
# current month df contains 108547 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-06-30'
# loading land-registry-data-archive/PPMS_update_2021_6_30.txt
# current month df contains 113620 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-07-31'
# loading land-registry-data-archive/PPMS_update_2021_7_31.txt
# current month df contains 92148 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-08-31'
# loading land-registry-data-archive/PPMS_update_2021_8_31.txt
# current month df contains 85703 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-09-30'
# loading land-registry-data-archive/PPMS_update_2021_9_30.txt
# current month df contains 97617 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-10-31'
# loading land-registry-data-archive/PPMS_update_2021_10_31.txt
# current month df contains 89449 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-11-30'
# loading land-registry-data-archive/PPMS_update_2021_11_30.txt
# current month df contains 132332 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2021-12-31'
# loading land-registry-data-archive/PPMS_update_2021_12_31.txt
# current month df contains 121144 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-01-31'
# loading land-registry-data-archive/PPMS_update_2022_1_31.txt
# current month df contains 137274 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-02-28'
# loading land-registry-data-archive/PPMS_update_2022_2_28.txt
# current month df contains 126641 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-03-31'
# loading land-registry-data-archive/PPMS_update_2022_3_31.txt
# current month df contains 125294 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-04-30'
# loading land-registry-data-archive/PPMS_update_2022_4_30.txt
# current month df contains 100998 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-05-31'
# loading land-registry-data-archive/PPMS_update_2022_5_31.txt
# current month df contains 110597 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-06-30'
# loading land-registry-data-archive/PPMS_update_2022_6_30.txt
# current month df contains 112345 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-07-31'
# loading land-registry-data-archive/PPMS_update_2022_7_31.txt
# current month df contains 110462 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-08-31'
# loading land-registry-data-archive/PPMS_update_2022_8_31.txt
# current month df contains 116431 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-09-30'
# loading land-registry-data-archive/PPMS_update_2022_9_30.txt
# current month df contains 113471 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-10-31'
# loading land-registry-data-archive/PPMS_update_2022_10_31.txt
# current month df contains 112190 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-11-30'
# loading land-registry-data-archive/PPMS_update_2022_11_30.txt
# current month df contains 120724 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2022-12-31'
# loading land-registry-data-archive/PPMS_update_2022_12_31.txt
# current month df contains 91668 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-01-31'
# loading land-registry-data-archive/PPMS_update_2023_1_31.txt
# current month df contains 123069 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-02-28'
# loading land-registry-data-archive/PPMS_update_2023_2_28.txt
# current month df contains 112406 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-03-31'
# loading land-registry-data-archive/PPMS_update_2023_3_31.txt
# current month df contains 107948 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-04-30'
# loading land-registry-data-archive/PPMS_update_2023_4_30.txt
# current month df contains 82888 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-05-31'
# loading land-registry-data-archive/PPMS_update_2023_5_31.txt
# current month df contains 88098 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-06-30'
# loading land-registry-data-archive/PPMS_update_2023_6_30.txt
# current month df contains 83269 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-07-31'
# loading land-registry-data-archive/PPMS_update_2023_7_31.txt
# current month df contains 93129 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-08-31'
# loading land-registry-data-archive/PPMS_update_2023_8_31.txt
# current month df contains 87678 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-09-30'
# loading land-registry-data-archive/PPMS_update_2023_9_30.txt
# current month df contains 76899 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-10-31'
# loading land-registry-data-archive/PPMS_update_2023_10_31.txt
# current month df contains 75242 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-11-30'
# loading land-registry-data-archive/PPMS_update_2023_11_30.txt
# current month df contains 100943 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2023-12-31'
# loading land-registry-data-archive/PPMS_update_2023_12_31.txt
# current month df contains 63083 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2024-01-31'
# loading land-registry-data-archive/PPMS_update_2024_1_31.txt
# current month df contains 96221 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2024-02-29'
# loading land-registry-data-archive/PPMS_update_2024_2_29.txt
# current month df contains 91103 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2024-03-31'
# loading land-registry-data-archive/PPMS_update_2024_3_31.txt
# current month df contains 83087 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2024-04-30'
# loading land-registry-data-archive/PPMS_update_2024_4_30.txt
# current month df contains 87644 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2024-05-31'
# loading land-registry-data-archive/PPMS_update_2024_5_31.txt
# current month df contains 78452 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []
# processing row data_timestamp_str='2024-06-30'
# loading land-registry-data-archive/pp-monthly-update-2024-06-30.txt
# current month df contains 100172 rows
# Empty DataFrame
# Columns: [transaction_unique_id, price, transaction_date, postcode, property_type, new_tag, lease, primary_address_object_name, secondary_address_object_name, street, locality, town_city, district, county, ppd_cat, record_status]
# Index: []

# %%
# add column for version
# df_months['version'] = None

# for transaction_unique_id, df_ in df_months.groupby('transaction_unique_id'):
#     df_['version'] =
df_months['version'] = df_months.groupby('transaction_unique_id').cumcount()

# %%
vc = df_months['transaction_unique_id'].value_counts()

# %%
vc[vc > 1]
# Out:
# transaction_unique_id
# {288DCE2A-15B1-E510-E050-A8C06205480E}    11
# {75050A86-15F9-9A88-E053-6B04A8C02390}    10
# {6DA0844A-D1FC-30F2-E053-6B04A8C05F3B}     9
# {25EA59FA-779E-4D50-E050-A8C0630562D0}     9
# {7011B10A-1EF1-8ED6-E053-6B04A8C075C1}     9
#                                           ..
# {93E6821F-3714-40FD-E053-6B04A8C0C1DF}     2
# {F3B6C199-5089-6E40-E053-6C04A8C0B3B4}     2
# {98C75471-B692-72E9-E053-6B04A8C042F0}     2
# {C18F412A-E84B-81A6-E053-6B04A8C0AD18}     2
# {8A78B2B0-5C51-5CB0-E053-6B04A8C0F504}     2
# Name: count, Length: 749427, dtype: int64

# %%
vc.max()
# Out:
# np.int64(11)

# %%
# example of large number of changes
df_months[df_months['transaction_unique_id'] == '{75050A86-15F9-9A88-E053-6B04A8C02390}']
# Out:
#                        transaction_unique_id    price  transaction_date  \
# 3334  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 2217  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 1422  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 1609  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 1250  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 1345  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 1332  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 912   {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 1041  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
# 1256  {75050A86-15F9-9A88-E053-6B04A8C02390}  4699400  2017-03-24 00:00
#
#       postcode property_type new_tag lease primary_address_object_name  \
# 3334  CH49 4SB             O       N     F                           3
# 2217  CH49 4SD             O       N     F                          21
# 1422  CH49 4SD             O       N     F                           9
# 1609  CH49 4SE             O       N     F                           2
# 1250  CH49 4SE             O       N     F                           5
# 1345  CH49 4SE             O       N     F                          10
# 1332  CH49 4SE             O       N     F                          12
# 912   CH49 4SD             O       N     F                          28
# 1041  CH49 4SE             O       N     F                           9
# 1256  CH49 4SD             O       N     F                          28
#
#      secondary_address_object_name               street locality town_city  \
# 3334                           NaN       HAREFIELDS WAY      NaN    WIRRAL
# 2217                           NaN        FAR HEY DRIVE      NaN    WIRRAL
# 1422                           NaN        FAR HEY DRIVE      NaN    WIRRAL
# 1609                           NaN  LITTLE MEADOW CLOSE  MORETON    WIRRAL
# 1250                           NaN  LITTLE MEADOW CLOSE  MORETON    WIRRAL
# 1345                           NaN  LITTLE MEADOW CLOSE  MORETON    WIRRAL
# 1332                           NaN  LITTLE MEADOW CLOSE  MORETON    WIRRAL
# 912                            NaN        FAR HEY DRIVE      NaN    WIRRAL
# 1041                           NaN  LITTLE MEADOW CLOSE  MORETON    WIRRAL
# 1256                           NaN        FAR HEY DRIVE      NaN    WIRRAL
#
#      district      county ppd_cat record_status  version
# 3334   WIRRAL  MERSEYSIDE       B             A        0
# 2217   WIRRAL  MERSEYSIDE       B             C        1
# 1422   WIRRAL  MERSEYSIDE       B             C        2
# 1609   WIRRAL  MERSEYSIDE       B             C        3
# 1250   WIRRAL  MERSEYSIDE       B             C        4
# 1345   WIRRAL  MERSEYSIDE       B             C        5
# 1332   WIRRAL  MERSEYSIDE       B             C        6
# 912    WIRRAL  MERSEYSIDE       B             C        7
# 1041   WIRRAL  MERSEYSIDE       B             C        8
# 1256   WIRRAL  MERSEYSIDE       B             C        9

# %%
# TODO: build `pp-complete.txt` for each month by going back progressively in time

for index in reversed(df_months.index):
    row = df_months.loc[index]

    record_status = row['record_status']

    if record_status == 'A':
        # delete all rows with matching TUID
        transaction_unique_id = row['transaction_unique_id']
        df = df[df['transaction_unique_id'] != transaction_unique_id]

    elif record_status == 'C':
        # row must be changed to previous version
        transaction_unique_id = row['transaction_unique_id']
        version = row['version']

        if version > 0:
            target_version = version - 1
            target_row = df_months[(df_months['transaction_unique_id'] == transaction_unique_id) & (df_months['version'] == target_version)]

            for column in df.columns:
                if column == 'transaction_unique_id':
                    continue
                df.loc[df['transaction_unique_id'] == transaction_unique_id][column] = target_row[column]
        else:
            raise RuntimeError(f'{version=}')

    elif record_status == 'D':
        # row must be added using previous values
        transaction_unique_id = row['transaction_unique_id']
        version = row['version']

        if version > 0:
            target_version = version - 1
            target_row = df_months[(df_months['transaction_unique_id'] == transaction_unique_id) & (df_months['version'] == target_version)]

            for column in df.columns:
                if column == 'transaction_unique_id':
                    continue
                df.loc[df['transaction_unique_id'] == transaction_unique_id][column] = target_row[column]
        else:
            raise RuntimeError(f'{version=}')

    else:
        raise RuntimeError(f'unrecognized {record_status=}')
# Out:
# /tmp/ipykernel_3612950/1290883713.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['transaction_unique_id'] == transaction_unique_id][column] = target_row[column]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 39
#      37         if column == 'transaction_unique_id':
#      38             continue
# ---> 39         df.loc[df['transaction_unique_id'] == transaction_unique_id][column] = target_row[column]
#      40 else:
#      41     raise RuntimeError(f'{version=}')
#
# File ~/Land-Registry-Data-Ingestion/Land-Registry-Download/venv/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/Land-Registry-Data-Ingestion/Land-Registry-Download/venv/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/Land-Registry-Data-Ingestion/Land-Registry-Download/venv/lib/python3.11/site-packages/pandas/core/series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File ~/Land-Registry-Data-Ingestion/Land-Registry-Download/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~/Land-Registry-Data-Ingestion/Land-Registry-Download/venv/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# KeyboardInterrupt:

# %%
tuid_pending_change = []
tuid_pending_undelete = []

for row in rows:
    pp_monthly_update_archive_file_log_id = row.pp_monthly_update_archive_file_log_id
    data_timestamp = row.data_timestamp
    data_timestamp_str = data_timestamp.strftime('%Y-%m-%d')
    print(f'processing row {data_timestamp_str=}')

    s3_bucket = row.s3_bucket
    s3_object_key = row.s3_object_key

    boto3_client = (
        boto3_session.client(
            's3',
            endpoint_url=minio_url,
            config=botocore.config.Config(signature_version='s3v4'),
        )
    )

    s3_response_object = boto3_client.get_object(Bucket=s3_bucket, Key=s3_object_key)
    pp_monthly_update_data = s3_response_object['Body'].read()

    df_current_month = pandas.read_csv(
        io.BytesIO(pp_monthly_update_data),
        header=None,
    )
    print(f'current month df contains {len(df_current_month)} rows')

    if len(df_current_month.columns) == 16:
        pass
    elif len(df_current_month.columns) == 15:
        df_current_month['ppd_cat'] = None
    else:
        raise RuntimeError(f'invalid number of columns: {len(df_current_month.columns)}')

    df_current_month.columns = df_columns

    # check no duplicate transaction_unique_id in this months dataframe
    df_current_month_tuid_value_counts = df_current_month['transaction_unique_id'].value_counts()
    assert df_current_month_tuid_value_counts.max() == 1, f'duplicate transaction_unique_id detected'

    # start of df manipulation

    for index, row in df_current_month[df_current_month['transaction_unique_id'].isin(tuid_pending_change)].iterrows():
        for column in df.columns:
            if column == 'transaction_unique_id':
                continue
            df[df['transaction_unique_id']][column] = row[column]

    for index, row in df_current_month[df_current_month['transaction_unique_id'].isin(tuid_pending_undelete)].iterrows():
        new_row_dict = {
            column: value for column, value in row.items()
        }
        # df.append(new_row_dict)
        df_new = pandas.DataFrame.from_records(
            [
                new_row_dict
            ]
        )
        df = pandas.concat(
            [df, df_new]
        )

    for index, row in reversed(df_current_month.iterrows()):
        record_status = row['record_status']

        if record_status == 'A':
            # delete all rows with matching TUID
            transaction_unique_id = row['transaction_unique_id']
            df = df[df['transaction_unique_id'] != transaction_unique_id]

        elif record_status == 'C':
            # row must be changed to previous version
            transaction_unique_id = row['transaction_unique_id']
            if not transaction_unique_id in tuid_pending_undelete:
                tuid_pending_change.append(transaction_unique_id)
            else:
                print(f'cannot add {transaction_unique_id=} to pending change, because exists in pending undelete')

        elif record_status == 'D':
            # row must be added using previous values
            transaction_unique_id = row['transaction_unique_id']
            if not transaction_unique_id in tuid_pending_change:
                tuid_pending_undelete.append(transaction_unique_id)
            else:
                print(f'cannot add {transaction_unique_id=} to pending undelete, because exists in pending change')

        else:
            raise RuntimeError(f'unrecognized {record_status=}')
# Out:
# processing row data_timestamp_str='2015-01-31'
# current month df contains 83245 rows
# 1
